# %%
# "Year","Mileage","Horsepower","Engine_Size","Weight","Top_Speed","Torque", "Acceleration_0_100"

# %%
# some more preprocessing: check for negative values

# %%
# Basic imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('../data/raw/Elite_Sports_Cars_in_Data.csv')

df.head()
# Out:
#        Brand           Model  Year Country Condition  Engine_Size  Horsepower  \
# 0     Nissan            720S  2006    Asia      used          3.7         420
# 1    McLaren     911 Turbo S  2009  Europe       new          5.3        1104
# 2  Chevrolet  M4 Competition  2009     USA       new          5.5         153
# 3    Bugatti          Chiron  1982    Asia      used          5.4         544
# 4     Nissan          Chiron  2022  Europe       new          2.4         980
#
#    Torque  Weight  Top_Speed  ...  Mileage Popularity Safety_Rating  \
# 0     705    1785        238  ...    96664        Low             2
# 1     766     992        386  ...   159630       High             2
# 2    1573    2022        397  ...   111496       High             1
# 3    1009    1091        151  ...   217228       High             2
# 4     693    1232        385  ...   150318        Low             3
#
#   Number_of_Owners  Market_Demand  Insurance_Cost  Production_Units  \
# ...

# %%
pp= df[["Year","Mileage","Horsepower","Engine_Size","Weight","Top_Speed","Torque", "Acceleration_0_100"]]

# %%
pp.head()
# Out:
#    Year  Mileage  Horsepower  Engine_Size  Weight  Top_Speed  Torque  \
# 0  2006    96664         420          3.7    1785        238     705
# 1  2009   159630        1104          5.3     992        386     766
# 2  2009   111496         153          5.5    2022        397    1573
# 3  1982   217228         544          5.4    1091        151    1009
# 4  2022   150318         980          2.4    1232        385     693
#
#    Acceleration_0_100
# 0                 5.7
# 1                 4.6
# 2                 6.7
# 3                 2.7
# 4                 3.0

# %%
pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                5000 non-null   int64
#  1   Mileage             5000 non-null   int64
#  2   Horsepower          5000 non-null   int64
#  3   Engine_Size         5000 non-null   float64
#  4   Weight              5000 non-null   int64
#  5   Top_Speed           5000 non-null   int64
#  6   Torque              5000 non-null   int64
#  7   Acceleration_0_100  5000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 312.6 KB

# %%
pp= df[["Year","Mileage","Horsepower","Engine_Size","Weight","Top_Speed","Torque", "Acceleration_0_100"]]

# %%
pp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                5000 non-null   int64
#  1   Mileage             5000 non-null   int64
#  2   Horsepower          5000 non-null   int64
#  3   Engine_Size         5000 non-null   float64
#  4   Weight              5000 non-null   int64
#  5   Top_Speed           5000 non-null   int64
#  6   Torque              5000 non-null   int64
#  7   Acceleration_0_100  5000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 312.6 KB

# %%
# this means that the dataset already is clean, the rest of the cleaninga nc checking is at the bottom of exploration notebook.

# %%
print(df[["Horsepower","Weight"]].dtypes)
print(df[["Horsepower","Weight"]].head(10))
# Out:
# Horsepower    int64
# Weight        int64
# dtype: object
#    Horsepower  Weight
# 0         420    1785
# 1        1104     992
# 2         153    2022
# 3         544    1091
# 4         980    1232
# 5        1091    2135
# 6         810    2130
# 7        1189    1526
# 8         230    1885
# 9         675    1472

# %%
# create the  important ratios: power to weight 
df["Power_Weight"] = df["Horsepower"]/df["Weight"]

# %%
# add car age'

current_timestamp = pd.Timestamp.now()
Current_Year = current_timestamp.year

# %%
print(df["Year"].unique()[:20])
print(df["Year"].dtype)
# Out:
# [2006 2009 1982 2022 1986 1988 2020 2021 1992 1994 1984 2008 2014 1987
#  2011 1999 1989 2010 2001 2000]
# int64

# %%
df["Car_Age"] = Current_Year - df["Year"]

# %%
# log for milage and weight. 
# logmileage exists.

# %%
df["Log_Weight"] = np.log1p(df["Weight"])

# %%
#now we put all of the features inside of the dataset. 
#Note year might not really have aushc a major effect. 
#

# %%
#check for the relationship of electric and other fuel types with the 0-60, and other ratios

# %%
# Torque to weight
df["Torque_Weight"] = df["Torque"] / df["Weight"]

# %%
#speed efficiency:
df["Speed_Efficiency"] = df["Top_Speed"] / df["Horsepower"]

# %%
#Mileage-to-age ratio: how aggresively the car was used.


df["Mileage_Per_Year"] = df["Mileage"] / df["Car_Age"].replace(0, 1)

# %%
Dataset= df[["Car_Age","Horsepower","Engine_Size","Log_Weight","Weight","Fuel_Type","Top_Speed","Torque","Power_Weight","Torque_Weight","Log_Mileage","Mileage_Per_Year","Speed_Efficiency","Acceleration_0_100"]]

# %%
Dataset.sort_values(by="Weight", ascending= True).head(50)
# Out:
#       Car_Age  Horsepower  Engine_Size  Log_Weight  Weight Fuel_Type  \
# 2008       39         957          2.5    6.803505     900  Electric
# 2832        9         521          6.8    6.804615     901  Electric
# 1491       24         547          2.0    6.805723     902    Diesel
# 1482       24         886          3.4    6.805723     902  Electric
# 613         6         363          6.0    6.805723     902    Diesel
# 2767       16        1258          2.2    6.806829     903  Electric
# 1494        2         444          7.3    6.806829     903    Petrol
# 3117       30         545          3.3    6.806829     903    Petrol
# 612        10         953          5.5    6.806829     903  Electric
# 2609       41         902          2.8    6.807935     904    Petrol
# 2761       26        1041          4.5    6.809039     905    Diesel
# 2756       34        1477          6.5    6.809039     905  Electric
# 718         2         441          4.9    6.809039     905    Petrol
# ...

# %%
#will need to use Neural Network since its a complex non-linear relationship: Multilayer Perceptron (MLP).

# %%
# Mid training note:
# - discovery of scrambled dataset:
# - why? Through checking correlations, we observed that they ranged close to zero, ie +-0.000x 

#     - solution: fix the dataset using values from the internet
# - result: ended up with the new updated dataset "5000_car_dataset_TRANSMISSION_FIXED_FINAL.csv"
# - New correlation:  +-0.0x
